# %% [markdown]
# El dataset VEDAI dispone de anotaciones de instancias en bandas RGB y NIR, lo que lo hace util para explorar el espacio n-dimensional generado por multiples bandas.
# - Primeramemte se veran 2 ejemplos de las imagenes contenidas en el dataset  y sus anotaciones.

# %%
#librerias por usar
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os

# %%
#Rutas de interes
r_folder = r"dataset_VEDAI"
r_annotations = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024"
r_images = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"

# %%
#leer archivos y el nombre del primer archivo
archivos_annotations = os.listdir(r_annotations)
archivos_images = os.listdir(r_images)
print("La primera anotacion se llama: ", archivos_annotations[0])
print("La primera imagen se llama: ","RGB:",archivos_images[0]," y ","NIR:", archivos_images[1])
# Out:
# La primera anotacion se llama:  00000000.txt
# La primera imagen se llama:  RGB: 00000000_co.png  y  NIR: 00000000_ir.png

# %% [markdown]
# Cada imgen le corresponde una anotacion, es importante mencionar las imagenes vienen dadas en pares, observando la salida anterior, cada umagen viene dada por un codigo numerico seguido de "_co" para RGB y "_ir" para banda NIR.

# %%
# Rutas completas a las dos primeras imágenes
ruta_img1 = os.path.join(r_images, archivos_images[0])
ruta_img2 = os.path.join(r_images, archivos_images[1])

# Leer imágenes
img_rgb1 = cv2.imread(ruta_img1)
img_nir1 = cv2.imread(ruta_img2)

# Separar canales RGB
b, g, r = cv2.split(img_rgb1)

# Para mostrar correctamente con matplotlib (que espera RGB)
r = cv2.cvtColor(r, cv2.COLOR_GRAY2RGB)
g = cv2.cvtColor(g, cv2.COLOR_GRAY2RGB)
b = cv2.cvtColor(b, cv2.COLOR_GRAY2RGB)

# Convertir NIR a escala de grises si viene como BGR
nir_gray = cv2.cvtColor(img_nir1, cv2.COLOR_BGR2GRAY)
nir = cv2.cvtColor(nir_gray, cv2.COLOR_GRAY2RGB)

# Plotear los 4 canales
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.imshow(r)
plt.title("Canal Rojo")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(g)
plt.title("Canal Verde")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(b)
plt.title("Canal Azul")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(nir)
plt.title("Canal NIR")
plt.axis("off")

plt.tight_layout()
plt.show()

# Combinarlas lado a lado
import numpy as np
img_nir1 = cv2.resize(img_nir1, (img_rgb1.shape[1], img_rgb1.shape[0]))
combinada = np.hstack((img_rgb1, img_nir1))

# Ajustar el tamaño del plot (en pulgadas)
plt.figure(figsize=(8, 4))  # más pequeño que el default
plt.title("Imagen RGB y NIR")
plt.imshow(combinada)
plt.axis("off")
plt.show()

# %% [markdown]
# Ahora bien, es importante poder visualizar de que forma estan dadas las anotaciones, asi que visualizaremos las anotaciones de la primera imagen en sus 4 canales.

# %%
#leemos el txt de la primera imagen.
ruta_anotacion1 = os.path.join(r_annotations,archivos_annotations[0])
with open(ruta_anotacion1, "r") as f:
    lineas = f.readlines()
print(lineas)
# Out:
# ['580.697942 1009.223279 3.012318 2 1 0 554 605 607 558 1004 996 1016 1021\n']

# %% [markdown]
# Como se interpretan estos numeros segun el formato? 580.697942 1009.223279 3.012318 2 1 0 554 605 607 558 1004 996 1016 1021
# - 580.697942 1009.223279 -> centroide del objeto (x, y).
# - 3.012318 -> ángulo de rotación del bounding box.
# - 2 1 0 -> etiquetas de clase
# - 554 605 607 558 1004 996 1016 1021 ->  las 4 esquinas del polígono (x1, x2, x3, x4, y1, y2, y3, y4).

# %%
# Cargar la imagen original desde archivo (limpia siempre)
img_original = cv2.imread(r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024\00000000_co.png")

# Crear copia para dibujar
img_dibujo = img_original.copy()

# Definir puntos manualmente
centroide = (580,1009)
pts = [(554, 1004),
        (605, 996), 
        (607, 1016),
          (558, 1021)]

# Dibujar puntos
for (x, y) in pts:
    cv2.circle(img_dibujo,centroide, 5, (255, 0, 0), -1)
cv2.circle(img_dibujo, (x, y), 5, (255, 0, 0), -1)
# Dibujar polígono
cv2.polylines(img_dibujo, [np.array(pts, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=2)

# Mostrar imagen
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(img_dibujo, cv2.COLOR_BGR2RGB))
plt.title("Prueba manual de anotaciones")
plt.axis("off")
plt.show()

# %% [markdown]
# Ahora, se generara un codigo que segun la imagen seleccionada del dataset se obtendra un histograma para cada canal trabajado.

# %%
# Ruta a la carpeta donde están tus imágenes
carpeta = "E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"

# Obtener lista ordenada de archivos
archivos = sorted(os.listdir(carpeta))

# Variable para elegir qué imagen graficar
imagen_para_plotear = 0  # empieza desde 0

# Calcular índices de la pareja
indice_co = imagen_para_plotear * 2     # canal RGB
indice_ir = imagen_para_plotear * 2 + 1 # canal IR

# Leer imágenes
img_co = cv2.imread(os.path.join(carpeta, archivos[indice_co]))
img_ir = cv2.imread(os.path.join(carpeta, archivos[indice_ir]), cv2.IMREAD_GRAYSCALE)

# Convertir BGR a RGB para matplotlib
img_co_rgb = cv2.cvtColor(img_co, cv2.COLOR_BGR2RGB)

# Separar canales RGB
b, g, r = cv2.split(img_co)

# --- Plot ---
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Mostrar imagen RGB
axes[0, 0].imshow(img_co_rgb)
axes[0, 0].set_title(f"Imagen RGB {imagen_para_plotear}")
axes[0, 0].axis("off")

# Mostrar imagen NIR
axes[0, 1].imshow(img_ir, cmap="gray")
axes[0, 1].set_title(f"Imagen NIR {imagen_para_plotear}")
axes[0, 1].axis("off")

# Histograma RGB
axes[1, 0].hist(r.ravel(), 256, [0, 256], color='r', alpha=0.6, label="Rojo")
axes[1, 0].hist(g.ravel(), 256, [0, 256], color='g', alpha=0.6, label="Verde")
axes[1, 0].hist(b.ravel(), 256, [0, 256], color='b', alpha=0.6, label="Azul")
axes[1, 0].set_title("Histograma RGB")
axes[1, 0].set_xlabel("Intensidad")
axes[1, 0].set_ylabel("Frecuencia")
axes[1, 0].legend()

# Histograma NIR
axes[1, 1].hist(img_ir.ravel(), 256, [0, 256], color='k', alpha=0.7, label="NIR")
axes[1, 1].set_title("Histograma NIR")
axes[1, 1].set_xlabel("Intensidad")
axes[1, 1].set_ylabel("Frecuencia")
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Es util poder visualizar un histograma de las imagenes en conjunto. De forma que se podrian observar caracteristicas generales del dataset.

# %%
#ACOMULA PIXELES Y LUEGO LOS GRAFICA, ES COMPUTACIONALMENTE MUY LENTO
# Carpeta de imágenes
carpeta = "E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"

# Variable que indica cuántos pares de imágenes (RGB+NIR) se van a procesar
num_pares = 10  # procesa los primeros 10 pares

# Obtener lista de archivos ordenados
archivos = sorted(os.listdir(carpeta))

# Limitar a los primeros pares (cada par tiene 2 imágenes)
archivos = archivos[:num_pares * 2]

# Listas para acumular los valores de píxeles
valores_r, valores_g, valores_b, valores_nir = [], [], [], []

# Recorrer archivos según su posición
for idx, archivo in enumerate(archivos):
    ruta = os.path.join(carpeta, archivo)
    img = cv2.imread(ruta, cv2.IMREAD_UNCHANGED)

    if img is None:
        continue

    if idx % 2 == 0:  # Imagen RGB
        b, g, r = cv2.split(img)
        valores_r.extend(r.flatten())
        valores_g.extend(g.flatten())
        valores_b.extend(b.flatten())
    else:  # Imagen NIR
        valores_nir.extend(img.flatten())

# Graficar histograma conjunto
plt.figure(figsize=(10, 6))
plt.hist(valores_r, bins=256, color='r', alpha=0.5, label='Rojo')
plt.hist(valores_g, bins=256, color='g', alpha=0.5, label='Verde')
plt.hist(valores_b, bins=256, color='b', alpha=0.5, label='Azul')
plt.hist(valores_nir, bins=256, color='k', alpha=0.5, label='NIR')

plt.title(f"Histograma conjunto de los primeros {num_pares} pares (RGB + NIR)")
plt.xlabel("Valor de intensidad")
plt.ylabel("Frecuencia")
plt.legend()
plt.show()

# %%
# Número de pares a procesar
num_pares = 200

# Listar imágenes en orden
imagenes = sorted(os.listdir(carpeta))

# Inicializar histogramas acumulados
hist_r = np.zeros((256,), dtype=np.float32)
hist_g = np.zeros((256,), dtype=np.float32)
hist_b = np.zeros((256,), dtype=np.float32)
hist_nir = np.zeros((256,), dtype=np.float32)

# Procesar solo los primeros num_pares pares
for i in range(num_pares):
    idx_rgb = 2 * i      # imagen RGB
    idx_nir = 2 * i + 1  # imagen NIR
    
    # Leer imágenes
    img_rgb = cv2.imread(os.path.join(carpeta, imagenes[idx_rgb]))
    img_nir = cv2.imread(os.path.join(carpeta, imagenes[idx_nir]), cv2.IMREAD_GRAYSCALE)
    
    # Calcular histogramas (cv2 los devuelve como matrices 256x1)
    hist_b += cv2.calcHist([img_rgb], [0], None, [256], [0, 256]).flatten()
    hist_g += cv2.calcHist([img_rgb], [1], None, [256], [0, 256]).flatten()
    hist_r += cv2.calcHist([img_rgb], [2], None, [256], [0, 256]).flatten()
    hist_nir += cv2.calcHist([img_nir], [0], None, [256], [0, 256]).flatten()

# Graficar histogramas acumulados
plt.figure(figsize=(9,3))
plt.plot(hist_r, color='red', label="Rojo")
plt.plot(hist_g, color='green', label="Verde")
plt.plot(hist_b, color='blue', label="Azul")
plt.plot(hist_nir, color='purple', label="NIR")
plt.title(f"Histograma acumulado de los primeros {num_pares} pares")
plt.xlabel("Intensidad (0-255)")
plt.ylabel("Frecuencia")
plt.legend()
plt.show()

# %% [markdown]
# De la distribucion de histograma de los primeros 200 pares podemos concluir varias cosas:
# - La distribucion de intensidades de los canales RGB esbastante similar, esto puede indicar un dataset con rango dinamico ya corregido para mejor visualizacion de la informacion
# - El pico que se observa en el NIR esta indicando una mayor reflectancia que en el visible, se podria hipotetizar que se debe a la presencia de vegetacion en las imagenes.
# - Mientras que RGB se concentra en el rango 80–150, el NIR está mucho más cargado hacia 170–200, esto significa que los objetos que aparecen en la escena tienen un comportamiento espectral distinto en visible y en NIR.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def visualizar_anotacion(annotations_folder, images_folder, index):
    """
    Visualiza los recortes de las anotaciones (bounding boxes) 
    para un índice dado de imagen.

    Params:
        annotations_folder: ruta a la carpeta de anotaciones (.txt)
        images_folder: ruta a la carpeta de imágenes (.png)
        index: número de la imagen (ej. 0 -> '00000000.txt')
    """
    # --- Buscar archivos ---
    base_name = f"{index:08d}"  # formato con ceros a la izquierda
    txt_path = os.path.join(annotations_folder, f"{base_name}.txt")
    img_path = os.path.join(images_folder, f"{base_name}_co.png")  # tomo la RGB

    if not os.path.exists(txt_path):
        raise FileNotFoundError(f"No existe anotación: {txt_path}")
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"No existe imagen: {img_path}")

    # --- Leer imagen ---
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # --- Leer anotaciones ---
    with open(txt_path, "r") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        parts = line.strip().split()
        if len(parts) < 11:
            continue  # línea inválida

        # Polígono de 4 esquinas
        xs = list(map(int, parts[6:10]))   # x1, x2, x3, x4
        ys = list(map(int, parts[10:14]))  # y1, y2, y3, y4
        polygon = np.array(list(zip(xs, ys)), dtype=np.int32)

        # Crear máscara para recortar el polígono
        mask = np.zeros(img.shape[:2], dtype=np.uint8)
        cv2.fillPoly(mask, [polygon], 255)

        # Aplicar la máscara
        recorte = cv2.bitwise_and(img, img, mask=mask)

        # Recortar el bounding box del polígono
        x_min, x_max = min(xs), max(xs)
        y_min, y_max = min(ys), max(ys)
        recorte_cuadro = recorte[y_min:y_max, x_min:x_max]

        # Mostrar resultado
        plt.figure()
        plt.imshow(recorte_cuadro)
        plt.title(f"Anotación {i+1} de {base_name}")
        plt.axis("off")
        plt.show()


# --------- USO ---------
annotations_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024"
images_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"

visualizar_anotacion(annotations_folder, images_folder, index=10)  # prueba con la primera imagen
 # prueba con el primer par

# %%
# Opcional: si tienes un mapeo id->nombre, ponlo aquí. Si no, usará "cls_{id}"
CLASS_MAP = {
    # 1: "car",
    # 2: "truck",
    # 3: "tractor",
    # 4: "bus",
    # 5: "boat",
    # ...
}

def visualizar_anotacion(annotations_folder, images_folder, output_folder, index):
    """
    Visualiza los recortes de las anotaciones (polígonos) para un índice dado
    y guarda cada recorte en una carpeta por clase.

    annotations_folder: carpeta con .txt (00000000.txt, ...)
    images_folder: carpeta con imágenes (00000000_co.png, 00000000_ir.png, ...)
    output_folder: carpeta raíz donde se guardarán los recortes clasificados
    index: número de imagen (ej. 0 -> '00000000.txt')
    """
    base_name = f"{index:08d}"
    txt_path = os.path.join(annotations_folder, f"{base_name}.txt")
    img_path = os.path.join(images_folder, f"{base_name}_co.png")  # usamos la RGB

    if not os.path.exists(txt_path):
        raise FileNotFoundError(f"No existe anotación: {txt_path}")
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"No existe imagen: {img_path}")

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    H, W = img.shape[:2]

    with open(txt_path, "r") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        parts = line.strip().split()
        if len(parts) < 14:
            continue  # línea inválida

        # -------- clase (¡ojo: viene en parts[3]!) --------
        try:
            cls_id = int(float(parts[3]))
        except ValueError:
            # si viniera algo raro, lo metemos como texto
            cls_id = str(parts[3])

        class_name = CLASS_MAP.get(cls_id, f"cls_{cls_id}")

        # -------- polígono --------
        # pueden venir floats, los redondeamos
        xs = [int(round(float(v))) for v in parts[6:10]]   # x1..x4
        ys = [int(round(float(v))) for v in parts[10:14]]  # y1..y4
        polygon = np.array(list(zip(xs, ys)), dtype=np.int32)

        # máscara y recorte
        mask = np.zeros((H, W), dtype=np.uint8)
        cv2.fillPoly(mask, [polygon], 255)
        recorte = cv2.bitwise_and(img, img, mask=mask)

        # bounding rect del polígono con límites de imagen
        x_min, x_max = max(0, min(xs)), min(W, max(xs))
        y_min, y_max = max(0, min(ys)), min(H, max(ys))
        if x_max <= x_min or y_max <= y_min:
            continue  # bbox degenerado

        recorte_cuadro = recorte[y_min:y_max, x_min:x_max]

        # -------- guardar por clase --------
        save_dir = os.path.join(output_folder, class_name)
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, f"{base_name}_{i+1}.png")
        cv2.imwrite(save_path, cv2.cvtColor(recorte_cuadro, cv2.COLOR_RGB2BGR))
        print(f"✅ Guardado: {save_path}")

        # Mostrar (opcional)
        #plt.figure()
        #plt.imshow(recorte_cuadro)
        #plt.title(f"{class_name} - Anotación {i+1} de {base_name}")
        #plt.axis("off")
        #plt.show()


# --------- USO ---------
annotations_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024"
images_folder      = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"
output_folder      = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados"

visualizar_anotacion(annotations_folder, images_folder, output_folder, index=10)


# --------- USO ---------
annotations_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024"
images_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"
output_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases"

visualizar_anotacion(annotations_folder, images_folder, output_folder, index=1)
# Out:
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_4\00000010_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_4\00000010_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_4\00000010_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_2\00000010_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_5\00000010_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_1\00000010_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_4\00000010_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_4\00000010_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\recortes_clasificados\cls_4\00000010_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000001_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000001_2.png

# %% [markdown]
# Operamos sobre un ciclo for para guardar cada clase  clasificada por carpeta

# %%
annotations_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024"
images_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Vehicules1024"
output_folder = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases"


inicio = 0
fin = 300   # o más grande si quieres

for i in range(inicio, fin):
    base_name = f"{i:08d}"  # mismo formato que tus nombres
    txt_path = os.path.join(annotations_folder, f"{base_name}.txt")

    if not os.path.exists(txt_path):
        print(f"Saltando {txt_path}, no existe.")
        continue

    visualizar_anotacion(
        annotations_folder, 
        images_folder, 
        output_folder,
        index=i,
    )
# Out:
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000000_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000001_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000001_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000002_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000003_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000004_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000004_2.png
# Saltando E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024\00000005.txt, no existe.
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000006_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000006_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000006_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000006_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000006_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000006_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000006_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000007_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000007_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000007_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000007_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000008_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000009_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000009_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000009_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000009_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000010_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000010_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000010_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000010_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000010_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000010_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000010_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000010_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000010_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000011_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000011_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000011_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000011_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000011_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000011_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000011_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000011_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000012_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000013_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000013_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000014_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000015_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000016_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000017_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000018_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000019_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000019_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000020_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000021_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000021_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000022_1.png
# Saltando E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024\00000023.txt, no existe.
# Saltando E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024\00000024.txt, no existe.
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000025_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000025_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000025_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000025_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000025_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000025_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000025_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000025_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000025_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000026_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000027_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000027_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000027_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000027_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000027_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000027_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000027_12.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000027_13.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000027_14.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_15.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000027_16.png
# Saltando E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024\00000028.txt, no existe.
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000029_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000030_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000030_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000030_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000030_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000030_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000030_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000031_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000032_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000032_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000032_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000033_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000033_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000033_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000033_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000033_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000033_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000033_7.png
# Saltando E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024\00000034.txt, no existe.
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000035_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000035_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000035_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000035_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000036_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000036_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000037_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000037_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000037_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000037_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000037_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000037_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000037_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000037_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000037_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000037_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000037_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000038_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000038_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000038_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000038_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000038_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000038_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000038_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000038_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000038_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000038_10.png
# Saltando E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\dataset_VEDAI\Annotations1024\00000039.txt, no existe.
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000040_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000040_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000041_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000041_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000041_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000041_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000041_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000041_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000041_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000041_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000042_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000042_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000043_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000043_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000043_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000043_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000043_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_12.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_13.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000043_14.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000044_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000044_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000044_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000044_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000044_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000044_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000044_12.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_13.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000044_14.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000044_15.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000044_16.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000044_17.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000045_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000045_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000045_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000045_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000045_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000045_12.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000046_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000046_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000046_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000046_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000047_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000047_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000047_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000047_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000047_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000047_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000048_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000048_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000048_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000048_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000048_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000048_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000048_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000048_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000048_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000049_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000049_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000049_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000049_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000049_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000049_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000049_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000049_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000049_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000049_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000049_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_9\00000049_12.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000049_13.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000049_14.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000049_15.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000050_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000050_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000050_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000050_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000050_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000050_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000050_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000050_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000050_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000050_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000051_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000051_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000051_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000051_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000051_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000051_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000051_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000051_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000051_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000051_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000052_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000052_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000052_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000052_11.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000053_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000053_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000053_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000053_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000053_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000053_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000053_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000054_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000054_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000054_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_31\00000054_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000055_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000055_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000055_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000055_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000056_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000056_2.png
# ...
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000277_12.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000277_13.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000277_14.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000277_15.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000277_16.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000277_17.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000277_18.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000278_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000278_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000278_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000278_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000278_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000278_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000278_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000278_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000279_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000279_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000280_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000281_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000281_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000281_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000281_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000282_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000282_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000282_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000282_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000282_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000282_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000283_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000283_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000283_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000283_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000284_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000284_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000284_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000284_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000284_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000284_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000284_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000284_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000285_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000285_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000285_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000286_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000286_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000286_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000286_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000286_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000286_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000286_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000286_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000287_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000288_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000288_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000288_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000289_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000290_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000291_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000291_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000291_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000291_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000291_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_23\00000291_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000292_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000293_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000294_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000295_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000295_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000295_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000295_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1\00000296_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000297_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000297_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000297_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000297_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000297_5.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000297_6.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000297_7.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000297_8.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000297_9.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000297_10.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000298_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000298_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_4\00000298_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000299_1.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_5\00000299_2.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_10\00000299_3.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_2\00000299_4.png
# ✅ Guardado: E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_11\00000299_5.png

# %% [markdown]
# Ahora que tenemos cada clase definida en una carptea, podemos realizar un histograma  para cada clase independientemente.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

r_datasets_por_clase = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases"

# Función para generar histograma de una carpeta de imágenes
def generar_histograma_por_clase(carpeta_clase, nombre_clase):
    canales = ['B', 'G', 'R']  # si tus imágenes tienen 3 canales
    histogramas = {c: [] for c in canales}

    for archivo in os.listdir(carpeta_clase):
        ruta_img = os.path.join(carpeta_clase, archivo)
        if os.path.isfile(ruta_img):
            img = cv2.imread(ruta_img)

            if img is None:
                continue

            # Calcular histograma por cada canal
            for i, canal in enumerate(canales):
                hist = cv2.calcHist([img], [i], None, [256], [0, 256])
                # Eliminar intensidades entre 0-15 y 252-255
                hist[0:16] = 0
                hist[252:256] = 0
                histogramas[canal].append(hist)

    # Sumar histogramas de todas las imágenes por canal
    hist_totales = {}
    for canal in canales:
        if histogramas[canal]:
            hist_totales[canal] = sum(histogramas[canal])
    
    # Encontrar el segundo valor máximo entre todos los histogramas
    todos_valores = np.concatenate([h.flatten() for h in hist_totales.values()])
    valores_ordenados = np.sort(todos_valores)[::-1]  # descendente
    if len(valores_ordenados) > 1:
        segundo_max = valores_ordenados[1]
    else:
        segundo_max = valores_ordenados[0]  # si solo hay un valor, usarlo

    # Graficar con normalización al segundo máximo
    plt.figure(figsize=(6, 2))
    for canal, hist_total in hist_totales.items():
        if segundo_max > 0:
            hist_escalado = hist_total * (segundo_max / hist_total.max())
        else:
            hist_escalado = hist_total
        # Mostrar desde 16 hasta 251
        plt.plot(range(16, 252), hist_escalado[16:252], label=f'Canal {canal}')
    
    plt.title(f"Histograma escalado (sin intensidades 0-15 ni 252-255) - {nombre_clase}")
    plt.xlabel("Intensidad")
    plt.ylabel("Frecuencia (escalada)")
    plt.legend()
    plt.show()

# Recorremos cada carpeta (cada clase)
for clase in os.listdir(r_datasets_por_clase):
    carpeta_clase = os.path.join(r_datasets_por_clase, clase)
    if os.path.isdir(carpeta_clase):
        generar_histograma_por_clase(carpeta_clase, clase)

# %% [markdown]
# El pico en el 0 indica los pixeles de relleno por el metodo de recorte, por lo que puede ser ignorado y se puede analizar el resto del histograma.

# %% [markdown]
# Ahora bien, con fin de continuar con los fines exploratorios, se generara una transformada de fourier para cada una de las clases con el fin de visualizar sus componentes.

# %%
# Ruta a las carpetas por clases
r_datasets_por_clase = r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases"

# --- Obtener resolución de referencia de la imagen ejemplo ---
img_ref = cv2.imread(r"E:\MACHINE LEARNING\AVANZADO 1\VSFOLDER A1 PROYECT\OT-Detecci-n-de-objetos-VIS-NIR-ML-Colombia\data_exploration\outputs\output_dataset_por_clases\cls_1_carros\00000006_1.png", cv2.IMREAD_GRAYSCALE)
ref_shape = img_ref.shape  # (alto, ancho)

def analizar_frecuencia_por_clase(dataset_path, ref_shape, umbral=10):
    clases = os.listdir(dataset_path)

    for clase in clases:
        clase_path = os.path.join(dataset_path, clase)
        if not os.path.isdir(clase_path):
            continue

        espectros = []
        for img_name in os.listdir(clase_path):
            img_path = os.path.join(clase_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            # Redimensionar a tamaño de referencia
            img_resized = cv2.resize(img, (ref_shape[1], ref_shape[0]))

            # Borrar pixeles de baja intensidad (relleno negro)
            _, img_clean = cv2.threshold(img_resized, umbral, 255, cv2.THRESH_TOZERO)

            # FFT
            f = np.fft.fft2(img_clean)
            fshift = np.fft.fftshift(f)
            magnitude_spectrum = 20 * np.log1p(np.abs(fshift))

            espectros.append(magnitude_spectrum)

        if espectros:
            # Promedio espectros
            espectro_promedio = np.mean(espectros, axis=0)

            # Mostrar espectro promedio
            plt.figure(figsize=(6,6))
            plt.imshow(espectro_promedio, cmap="gray")
            plt.title(f"Transformada de Fourier promedio - {clase}")
            plt.axis("off")
            plt.show()

analizar_frecuencia_por_clase(r_datasets_por_clase, ref_shape)
